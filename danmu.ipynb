# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re

# %%
browser = webdriver.Chrome()

# %%
browser.get('https://www.douyu.com/110')

# %%
danmu = browser.find_elements_by_xpath('//ul[@class="c-list"]/li')
d_list = []

# %%
while True:
    danmu = browser.find_elements_by_xpath('//ul[@class="c-list"]/li')
    if last == None or last ==danmu[0].text:
        with open('danmu.txt', 'a+') as f:
            for dm in danmu:
                f.write(dm.text)
                print(dm.text,'|*|', end='')
        last = danmu[-1]
    time.sleep(.1)

# %%
html = browser.page_source

# %%
html_ = BeautifulSoup(html, 'lxml')

# %%
print(html_.prettify())
# Out:
# <!DOCTYPE html>
# <html class="left-menu-small" style="overflow: auto;" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    yyfyyf直播_DOTA2直播_斗鱼
#   </title>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="webkit" name="renderer"/>
#   <link href="https://www.douyu.com/9999" rel="canonical"/>
#   <meta content="yyfyyf,yyfyyf直播,yyfyyf直播间,yyfyyf直播地址,DOTA2直播,yyfyyfDOTA2精彩视频" name="keywords"/>
#   <meta content="欢迎来到主播yyfyyf的斗鱼9999DOTA2直播间,本直播间提供最精彩的yyfyyfDOTA2直播,yyfyyf带你领略最有趣的DOTA2视频直播。" name="description"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script src="//hm.baidu.com/hm.js?e99aee90ec1b2106afe7ec3b199020a7">
#   </script>
#   <script type="text/javascript">
#    var $SYS = {"cookie_pre":"acf_","web_url":"https:\/\/shark.douyucdn.cn\/","upload_url":"https:\/\/staticlive.douyucdn.cn\/upload\/","res_url":"https:\/\/staticlive.douyucdn.cn\/common\/","res_flash_url":"https:\/\/www.douyu.com\/common\/","res_ver":"v8.173","resource_url":"https:\/\/res.douyucdn.cn\/resource\/","swf_ver":"v8.449","avatar_url":"https:\/\/apic.douyucdn.cn\/","sign_url":"https:\/\/staticlive.douyucdn.cn\/storage\/","sign_newver":true,"pay_site_host":"https:\/\/cz.douyu.com","storage_cdn":"https:\/\/staticlive.douyucdn.cn\/storage\/webpic_resources\/upload\/","tvk":"ccn","tn":"ctn","fh":"https:\/\/dotcounter.douyucdn.cn\/deliver\/fish","fh2":"https:\/\/dotcounter.douyucdn.cn\/deliver\/fish2","fh_edge":"https:\/\/uact.douyucdn.cn\/uact.do","fh_deliver":"https:\/\/apm.douyucdn.cn\/deliver\/perform","ucp_front":"https:\/\/ucp.douyucdn.cn\/ucp.do","webconfUrl":"https:\/\/webconf.douyucdn.cn\/","pmChatPopwindUrl":"https:\/\/msgstatic.douyu.com","yubaDomain":"\/\/yuba.douyu.com\/","vsite_url":"https:\/\/v.douyu.com","wapHost":"https:\/\/m.douyu.com\/","ceph_url":"https:\/\/club-img.douyucdn.cn\/","giftHost":"https:\/\/www.douyu.com"};
#     var $DYS = {};
#     $DYS['page_init_time'] = new Date().getTime();
#         window.passport_host = '//passport.douyu.com/';
#     window.client_id = '1';
#   </script>
#   <script charset="utf-8" src="https://shark.douyucdn.cn/perform/dist/dyl.js?171030" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="https://shark.douyucdn.cn/app/douyu/js/com/device.js?nv=v8.173" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $SYS.is_live_page = 1;
#   </script>
#   <style type="text/css">
#    input::-ms-clear{display:none}html{background:#fff;color:#3c3c3c;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}body{-webkit-font-smoothing:antialiased}article,aside,blockquote,body,button,code,dd,details,div,dl,dt,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,hr,input,legend,li,menu,nav,ol,p,pre,section,td,textarea,th,ul{margin:0;padding:0}body,button,input,select,textarea{font:12px/1.5 \5FAE\8F6F\96C5\9ED1,arial,sans-serif}input,select,textarea{font-size:100%}table{border-collapse:collapse;border-spacing:0}th{text-align:inherit}fieldset,img{border:none}iframe{display:block}abbr,acronym{border:none;font-variant:normal}del{text-decoration:line-through}address,caption,cite,code,dfn,em,th,var{font-style:normal;font-weight:500}ol,ul{list-style:none}caption,th{text-align:left}h1,h2,h3,h4,h5,h6{font-size:100%;font-weight:500}q:after,q:before{content:""}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}a,a:hover,ins{text-decoration:none}:focus,a:focus{outline:none}.clearfix:after,.clearfix:before{content:"";display:table}.clearfix:after{clear:both;overflow:hidden}.clearfix{zoom:1}.clear{clear:both;display:block;font-size:0;height:0;line-height:0;overflow:hidden}.fl,.fr{display:inline}.fl{float:left}.fr{float:right}.hide{display:none!important}.block{display:block}.scroll-none{overflow:hidden}.scroll-all{overflow:auto}.scroll-x{overflow-x:auto;overflow-y:hidden}.scroll-y{overflow-x:hidden;overflow-y:auto}textarea{resize:none;padding:0;margin:0}.ellipsis{overflow:hidden;text-overflow:ellipsis;white-space:nowrap;word-wrap:normal;word-break:keep-all}#header{position:fixed;top:0;left:0;z-index:500;width:100%;height:50px;background:#f5f5f5;border-bottom:1px solid #d1d1d1;transform:translateZ(0);-webkit-transform:translateZ(0)}#header .placeholder{color:#aaa}#header .icofont{display:inline-block;width:18px;height:20px}#header .head{margin:0 auto;width:1493px;position:relative;z-index:103;height:50px}#header .head-logo{display:block;height:50px;width:88px}#header .head-logo a{display:inline-block;zoom:1}#header .head-logo .header-vam{display:inline-block;zoom:1;width:0;height:100%}#header .head-nav{padding:10px 0 0 39px;height:40px;position:relative}#header .w1366head,#header .w1520head{width:1200px}#header .w1366head .head-logo,#header .w1520head .head-logo{margin-left:0}#header .head-nav&gt;li{font-size:20px;line-height:30px;width:63px;height:30px;margin:0 8px;text-align:center;position:relative}#header .head-nav&gt;li&gt;a{display:block;color:#444}#header .head-nav&gt;li&gt;a:hover{color:#ff630e}#header .head-nav&gt;li.current a{color:#fff;background:#ff630e;border-radius:3px}#header .head-nav .assort&gt;i{position:absolute;right:-12px;top:14px;width:9px;height:5px;overflow:hidden;padding:0;font-size:0;line-height:0;transition:all .3s ease-in-out;-o-transition:all .3s ease-in-out;-moz-transition:all .3s ease-in-out;-webkit-transition:all .3s ease-in-out}#header .head-nav&gt;li.funny{margin-left:15px}#header .head-nav .funny .g_hot_icon,#header .head-nav .yugou-mall .mall-icon{display:block;width:22px;height:16px;position:absolute;top:-2px;right:-12px}#header .head-nav .assort .a-pop{padding:10px 15px 12px;width:247px;position:absolute;right:-107px;top:40px;display:none;background:#fff;border:1px solid #ddd;border-bottom-left-radius:4px;border-bottom-right-radius:4px}#header .head-nav .assort .a-pop&gt;i{top:-7px;right:50%;margin-right:-7px;border-bottom:7px solid #ddd}#header .head-nav .assort .a-pop&gt;i,#header .head-nav .assort .a-pop&gt;i:after{width:0;height:0;position:absolute;border-top:0;border-left:7px solid transparent;border-right:7px solid transparent}#header .head-nav .assort .a-pop&gt;i:after{content:"";top:1px;right:-7px;border-bottom:7px solid #fff}#header .head-nav .assort .a-list h3{margin:8px 0 4px;color:#444;font-size:14px;line-height:22px;font-weight:700;font-family:microsoft yahei;text-align:left}#header .head-nav .assor ...
#    .immediate-aab655{transition-duration:0s!important}.hcenter-ad54e7{left:50%;-webkit-transform:translateX(-50%);transform:translateX(-50%)}.vcenter-b4e3e2{top:50%;-webkit-transform:translateY(-50%);transform:translateY(-50%)}.center-03f8d7{left:50%;top:50%;-webkit-transform:translateX(-50%) translateY(-50%);transform:translateX(-50%) translateY(-50%)}.mouse-disable-7ca394{pointer-events:none}.mouse-disable-7ca394&gt;*{pointer-events:auto}.ad-corner-a7dbc6{position:absolute;background-color:rgba(0,0,0,.2);width:25px;height:15px;line-height:15px;bottom:0;left:2px;border-radius:3px;text-align:center;color:#fff;font-family:Microsoft YaHei;font-size:12px;-webkit-transform-origin-x:0;-webkit-transform:scale(.75)}.error-620566{position:absolute;background:red;color:#fff;z-index:999}
#   </style>
#   <style type="text/css">
#    .comment-2fc131{position:absolute;left:0;top:0;overflow:hidden;pointer-events:none;z-index:0}.hidden-246eaa{display:none!important}
#   </style>
#   <style type="text/css">
#    .danmu-6e95c1{left:0;top:0;overflow:hidden}.danmu-6e95c1,.danmuItem-31f924{position:absolute;pointer-events:none}.danmuItem-31f924{user-select:none;white-space:nowrap;perspective:500px;display:inline-block;will-change:transform;text-shadow:#000 0 0 1px,#000 0 0 1px,#000 0 0 1px}.danmuItem-31f924&gt;*{pointer-events:none}
#   </style>
#   <style type="text/css">
#    .link-259efb{display:flex;flex-direction:row;align-items:center}.icon-059ac1{display:inline-flex;background:url(data:image/png;base64,...) 100% 100% no-repeat;width:26px;height:26px}.text-fe073a{display:inline-flex;flex-direction:row;align-items:center;margin-left:14px}.text-fe073a:before{background:url(...) no-repeat;width:7px;margin-right:6px}.text-fe073a:after,.text-fe073a:before{content:" ";display:inline-flex;height:26px}.text-fe073a:after{background:url(...) no-repeat;width:8px;margin-left:6px}
#   </style>
#   <style type="text/css">
#    .host-dfb9d8{background:linear-gradient(90deg,hsla(0,0%,100%,.2) 0,hsla(0,0%,100%,.2) 80%,hsla(0,0%,100%,0));height:52px;border-radius:26px}.icon-0f64d8{display:inline-block;width:42px;height:42px;border-radius:21px;margin-left:9px;margin-top:5px;vertical-align:top}.hostname-c057ee,.text-f128d7{display:inline-block;margin-left:10px;font:700 24px Microsoft YaHei;line-height:52px}.text-f128d7{margin-right:140px}
#   </style>
#   <style type="text/css">
#    .noble-bf13ad{background:linear-gradient(90deg,hsla(0,0%,100%,.2) 0,hsla(0,0%,100%,.2) 80%,hsla(0,0%,100%,0));height:42px;border-radius:21px}.user-icon-8af1e3{display:inline-block;width:35px;height:35px;border-radius:17.5px;margin-left:4.5px;margin-top:3.5px}.noble-icon-c10b6a{display:inline-block;width:22px;height:22px;border-radius:11px;margin-left:-8.85px;margin-top:17.55px}.text-b132b0{display:inline-block;margin-left:8px;margin-right:20px;height:42px;line-height:42px!important;vertical-align:top}
#   </style>
#   <style type="text/css">
#    .noble-2c3f56{background:linear-gradient(90deg,hsla(0,0%,100%,.2) 0,hsla(0,0%,100%,.2) 80%,hsla(0,0%,100%,0));height:42px;border-radius:21px}.activity-icon-c717fc{display:inline-block;width:26px;height:26px;border-radius:13px;margin-left:4.5px;margin-top:8px;vertical-align:top}.user-icon-eeabb1{display:inline-block;width:35px;height:35px;border-radius:17.5px;margin-left:4.5px;margin-top:3.5px}.noble-icon-88f562{display:inline-block;width:22px;height:22px;border-radius:11px;margin-left:-8.85px;margin-top:17.55px}.text-a4eb25{display:inline-block;margin-left:8px;margin-right:20px;height:42px;line-height:42px!important;vertical-align:top}
#   </style>
#   <style type="text/css">
#    .activity-icon-4b45df{width:26px;height:26px;border-radius:13px}.activity-icon-4b45df,.text-313648{display:inline-block;vertical-align:middle}.text-313648{margin-left:8px;height:30px;line-height:30px!important}
#   </style>
#   <style type="text/css">
#    .micro-b3e56f{width:160px;height:230px;-webkit-mask-image:url(data:image/png;base64,...)}.bg-2b1d34,.circle-03bbb8,.micro-b3e56f{position:absolute}.bg-2b1d34{width:228px;height:298px;left:-35px;top:-35px;-webkit-filter:blur(6px);-moz-filter:blur(6px);-ms-filter:blur(6px);filter:blur(6px)}.avatar-25a6a0{position:absolute;width:86px;height:86px;left:37px;top:72px;border-radius:43px}
#   </style>
#   <style type="text/css">
#    .removed-dca20a{display:none}.controlbar-a2580a{position:absolute;height:42px;bottom:0;background-color:#23272b;transition:opacity .5s ease-out,-webkit-transform .5s ease-out;transition:transform .5s ease-out,opacity .5s ease-out;transition:transform .5s ease-out,opacity .5s ease-out,-webkit-transform .5s ease-out}.hide-9576e1{opacity:0;-webkit-transform:translateY(42px);transform:translateY(42px)}.tips-dedd1d{position:absolute;transition:opacity .5s ease-out,-webkit-transform .5s ease-out;transition:transform .5s ease-out,opacity .5s ease-out;transition:transform .5s ease-out,opacity .5s ease-out,-webkit-transform .5s ease-out;width:100%;height:42px;bottom:0}.hide2-b8bcb1{-webkit-transform:translateY(42px);transform:translateY(42px)}.controlbar-a2580a .container-7950e8{display:flex;height:25px;line-height:25px;margin-top:8.5px;flex-wrap:nowrap}.body-flash-fullpage .controlbar-a2580a .container-7950e8{min-width:800px}.controlbar-a2580a .container-7950e8 .left-a5dc5a{display:flex;flex:1;height:100%}.controlbar-a2580a .container-7950e8 .right-9eac0f{height:100%}.controlbar-a2580a .play-48c8c5{float:left;width:16px;height:100%;margin-left:14px;background:url(data:image/png;base64,...) no-repeat 0;cursor:pointer}.controlbar-a2580a .play-48c8c5:hover{background-image:url(data:image/png;base64,...)}.controlbar-a2580a .pause-81a5c3{float:left;width:16px;height:100%;margin-left:14px;background:url(...) no-repeat 0;cursor:pointer}.controlbar-a2580a .pause-81a5c3:hover{background-image:url(...)}.controlbar-a2580a .reload-d03bc3{float:left;width:23px;height:100%;margin-left:14px;background:url(data:image/png;base64,...) no-repeat 50%;cursor:pointer}.controlbar-a2580a .reload-d03bc3:hover{background-image:url(data:image/png;base64,...)}.controlbar-a2580a .feedback-e6fc2b{float:left;width:16px;height:100%;margin-right:14px;background:url(...) no-repeat 50%;cursor:pointer}.controlbar-a2580a .feedback-e6fc2b:hover{background-image:url(...)}.controlbar-a2580a .volume-acb807{float:left;width:20px;height:100%;margin-right:6px;background:url(data:image/png;base64,...) no-repeat 0;cursor:pointer}.controlbar-a2580a .volume-silent-81a4be{float:left;width:20px;height:100%;margin-right:6px;background:url(data:image/png;base64,...) no-repeat 0;cursor:pointer}.controlbar-a2580a .showdanmu-f76338{background:url(data:image/png;base64,...) no-repeat 50%}.controlbar-a2580a .hidedanmu-753bb7,.controlbar-a2580a .showdanmu-f76338{float:left;width:79px;height:23px;margin-right:14px;margin-top:2px;cursor:pointer}.controlbar-a2580a .hidedanmu-753bb7{background:url(data:image/png;base64,...) no-repeat 50%}.controlbar-a2580a .seting-4a2169{float:left;width:18px;height:100%;margin-right:14px;background:url(data:image/png;base64,...) no-repeat 50%;cursor:pointer}.controlbar-a2580a .seting-4a2169:hover{background-image:url(data:image/png;base64,...)}.controlbar-a2580a .wfs-7ab3fc{float:left;width:18px;height:100%;margin-right:14px;background:url(data:image/png;base64,...) no-repeat 50%;cursor:pointer}.controlbar-a2580a .wfs-7ab3fc:hover{background-image:url(data:image/png;base64,...)}.controlbar-a2580a .wfs-exit-f6eb46{float:left;width:18px;height:100%;margin-right:14px;background:url(data:image/png;base64,...) no-repeat 50%;cursor:pointer}.controlbar-a2580a .wfs-exit-f6eb46:hover{background-image:url(data:image/png;base64,...)}.controlbar-a2580a .fs-70cde8{float:left;width:18px;height:100%;margin-right:14px;background:url(data:image/png;base64,...) no-repeat 50%;cursor:pointer}.controlbar-a2580a .fs-70cde8:hover{background-image:url(data:image/png;base64,...)}.controlbar-a2580a .fs-exit-b647e3{float:left;width:18px;height:100%;margin-right:14px;background:url(data:image/png;base64,...) no-repeat 50%;cursor:pointer}.controlbar-a2580a .fs-exit-b647e3:hover{background-image:url(data:image/png;base64,...)}.controlbar-a2580a .enter-ed35cb{float:left;padding-left:8px;padding-right:5px;height:100%;margin-right:14px;background:#ff8e01;border-radius:4px;cursor:pointer}.co ...
#   </style>
#   <style type="text/css">
#    .volume-bar-7b22e6{position:relative;float:left;width:100px;height:100%;margin-right:6px;cursor:pointer}.volume-bar-7b22e6 .back-361b0e{background:#15191c}.volume-bar-7b22e6 .back-361b0e,.volume-bar-7b22e6 .front-d6efcd{position:absolute;width:100%;height:8px;border-radius:4px;pointer-events:none}.volume-bar-7b22e6 .front-d6efcd{background:#fc831a}.volume-bar-7b22e6 .point-4ae5f8{position:absolute;left:50px;width:13px;height:12px;background:url(data:image/png;base64,...) no-repeat 50%;pointer-events:none}.tips-236b6e{margin-top:-20px;width:60px;text-align:center;background:#fff}.tips2-8649ed{margin-left:0;text-align:center}
#   </style>
#   <style type="text/css">
#    .setting-910a97{position:relative;float:left;width:18px;height:17px;margin-right:14px}.settingPanel-99937c{position:absolute;margin-top:-176px;width:198px;height:156px;margin-left:-138px;background-color:rgba(43,43,43,.8);border-width:1px;border-style:solid}.settingButton-c9a194{float:right;width:18px;height:17px;margin-top:4px;background:url(data:image/png;base64,...) no-repeat 50%;cursor:pointer;position:absolute}.settingButton-c9a194:hover{background-image:url(data:image/png;base64,...)}.row1-fb3975{width:173px;height:24px;margin-left:12px;margin-top:16px}.fullScreenDanmuOpen-68a957{background:url(data:image/png;base64,...) no-repeat 50%}.fullScreenDanmuClose-123afd,.fullScreenDanmuOpen-68a957{position:absolute;float:left;width:88px;height:23px;cursor:pointer;margin-left:90px}.fullScreenDanmuClose-123afd{background:url(data:image/png;base64,...) no-repeat 50%}.fullScreenDanmuLabel-61f0ab{width:86px;position:absolute;font-size:14px;color:#fff}.line1-31707f{width:173px;height:1px;background-color:#4b4a4a;margin-left:12px;margin-top:8px}.transparentLabel-11ba49{width:86px;position:absolute;font-size:14px;color:#fff;margin-left:12px;margin-top:5px}.transparentButtons-c56717{width:173px;position:absolute;height:22px;margin-left:20px;margin-top:39px}.transparentButton1-094f8c,.transparentButton2-ca910a,.transparentButton3-d6d9ed{float:left;width:26px;font-size:12px;color:#898989;margin-right:4px}.transparentButton4-715dd7{width:26px;font-size:12px;color:#898989;float:left}.verticalLine1-f73c6c,.verticalLine2-65b095,.verticalLine3-55d051{width:1px;height:22px;background-color:#858484;float:left;margin-right:17px}.line2-a59cb1{width:173px;height:1px;position:absolute;background-color:#4b4a4a;margin-left:12px;margin-top:74px}.danmuModel1-7569c8{float:left;width:42px;height:48px;background:url(...) no-repeat 50%;cursor:pointer;margin-right:24px}.danmuModel1select-993e79{background:url(...) no-repeat 50%}.danmuModel1select-993e79,.danmuModel2-4653f7{float:left;width:42px;height:52px;cursor:pointer;margin-right:24px}.danmuModel2-4653f7{background:url(...) no-repeat 50%}.danmuModel2select-709bd1{background:url(...) no-repeat 50%;margin-right:24px}.danmuModel2select-709bd1,.danmuModel3-3ac94d{float:left;width:42px;height:52px;cursor:pointer}.danmuModel3-3ac94d{background:url(...) no-repeat 50%}.danmuModel3select-0e1998{float:left;width:42px;height:52px;background:url(...) no-repeat 50%;cursor:pointer}.danmuModels-3a863f{position:absolute;margin-left:12px;margin-top:89px;width:175px}
#   </style>
#   <style type="text/css">
#    .shieldSetting-c3af04{position:relative;float:left;width:19px;height:19px;margin-right:14px}.shieldSettingPanel-3890af{position:absolute;margin-top:-100px;width:114px;height:96px;margin-left:-50px;background:url(data:image/png;base64,...)}.settingButton-8f027a{width:19px;height:19px;background:url(data:image/png;base64,...) no-repeat 50%}.settingButton2-e356e3,.settingButton-8f027a{float:right;margin-top:4px;cursor:pointer;position:absolute}.settingButton2-e356e3{width:18px;height:17px;background:url(data:image/png;base64,...) no-repeat 50%}.shieldSettingItem-c859bb{position:absolute;width:97px;height:20px;cursor:pointer;margin-left:10px}.shieldSettingItemButton-4646fe{position:absolute;width:13px;height:13px;background:url(...)}.shieldSettingItemButton2-a4dca5{position:absolute;width:12px;height:13px;background:url(...)}.shieldSettingLabel-5d4a78{position:absolute;color:#fff;font-size:12px;margin-left:20px;margin-top:-4px;pointer-events:none}
#   </style>
#   <style type="text/css">
#    .rate-e5b9df{position:relative;float:left;height:100%;margin-right:14px;background:#15191c;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.rate-e5b9df .text-0ff253{height:100%;cursor:pointer;padding-left:10px;padding-right:10px;font-size:12px;color:#ffa11a}.rate-e5b9df .textLabel-1cfd3f{height:100%;cursor:pointer;font-size:12px;color:#ffa11a;pointer-events:none}.tip-63dca6{position:absolute;border:1px solid #000;border-radius:4px;background:#1d1d1e;-webkit-transform:translateY(calc(-4px - 100%)) translateX(-50%);transform:translateY(calc(-4px - 100%)) translateX(-50%);left:50%;top:0}.tip-63dca6 ul{margin:0;padding:2px 0;list-style:none}.tip-63dca6 ul li{padding:2px 10px;white-space:nowrap;color:#999;text-align:center;cursor:pointer}.tip-63dca6 ul li:hover{color:#f7f7f7}.tip-63dca6 ul .selected-cd06e5{color:#ffa11a;pointer-events:none;cursor:default}
#   </style>
#   <style type="text/css">
#    .hint-6b4cb1{position:absolute;width:100%;height:30px;background:rgba(0,0,0,.6);color:#fff;font-size:14px;text-align:left;padding-top:10px;padding-left:10px}.close-afb878{width:12px;height:12px;background:url(data:image/png;base64,...) no-repeat;margin-top:12px;top:0;right:20px}.buy-e5aa06,.close-afb878{position:absolute;cursor:pointer}.buy-e5aa06{color:#f70}
#   </style>
#   <style type="text/css">
#    .quickChatBarView-1123bb{position:absolute;width:660px;height:46px;left:50%;margin-left:-310px;bottom:105px;background:rgba(0,0,0,.3)}.inputView-0d3a7f{margin-left:8px;width:536px;background-color:rgba(239,239,239 .6);border:0;cursor:default}.inputView-0d3a7f,.sendDanmu-bd5470{position:absolute;margin-top:8px;height:28px}.sendDanmu-bd5470{width:108px;margin-left:544px;cursor:pointer;text-align:center;line-height:22px;font-size:12px;color:#fff}.sendDanmu-bd5470,.sendDanmu-bd5470:hover{background:#ff921a}
#   </style>
#   <style type="text/css">
#    .loadingView-8e076f{position:absolute;width:100%;height:100%;background-color:#333;align-items:center;display:flex;justify-content:center}.content-bcc6a5{text-align:center}.switchBox-6700ec{height:40px;margin:14px auto}.tip-b0e187{margin:auto;width:110px;height:42px;background:url(https://shark.douyucdn.cn/app/douyu-liveH5/live/img/state/loading_text.gif?2d0f27) no-repeat}.reload-f4511d{width:100px;height:42px;background:url(data:image/png;base64,...);margin:auto;cursor:pointer}.reload-f4511d:hover{background-image:url(data:image/png;base64,...)}
#   </style>
#   <style type="text/css">
#    .menu-753ad0{position:absolute;display:none;top:0;left:0;margin:0;padding:0;border:1px solid #e5e5e5;box-shadow:2px 2px 8px #333;background:#fff;min-width:200px}.menu-753ad0 li{list-style:none;cursor:pointer;padding:5px 20px;font-size:12px;line-height:1.8}.menu-753ad0 .disable-8f2da9{color:#a9a9a9;cursor:default}.menu-753ad0 li:not(.disable-8f2da9){transition:background .1s}.menu-753ad0 li:not(.disable-8f2da9):hover{background:#e5e5e5}.menu-753ad0 .divider-8960ad{width:100%;height:1px;background:#e5e5e5;margin:2px auto}
#   </style>
#   <style type="text/css">
#    .wenti1-fafd3e{border:0;position:absolute;top:0;left:0;width:450px;height:428px;top:50%;left:50%;margin-top:-214px;margin-left:-225px}.content1-adc097{margin:0 auto;height:428px}.content1-adc097,.title-de1543{position:relative;width:450px;border:none}.title-de1543{height:36px;padding:0;margin:0;background:url(...)}.bg-30dec0{border:none;position:relative;width:450px;height:392px;padding:0;margin-top:-5px;background:url(...)}.content2-7f05d4{border:0;position:relative;padding:0;margin-top:-418px}.formCss1-526462{padding-top:48px;margin-left:14px;width:434px;font-size:14px}.radiocss2-0b9624{position:relative;margin-left:.1px;display:inline}.radiocss-bfb04d{margin-left:48px}.radiocss1-aafe2d,.radiocss-bfb04d{position:relative;font-size:14px;display:inline}.radiocss1-aafe2d{margin-left:.1px}.formCss1-526462 label,.formCss1-526462 span{margin-left:6px}.formCss1-526462 input{width:16px;height:16px;margin-top:7px}.c1-1f7f28{margin-top:8px}.c2-35a777{width:300px;height:22px;margin-left:80px}.c3-eeb27b{height:26px;margin-left:16px;width:116px;direction:center}.c4-2ee4f5{width:50px;margin-left:14px}.c4-2ee4f5,.c5-9b0f43{background-color:transparent;border:none}.c5-9b0f43{width:65px;margin-left:40px}.c6-5124ae{background-color:transparent;border:none;width:60px;margin-left:14px}.c7-56905f{display:inline;margin-left:16px}.c8-accc15{margin-left:14px;width:320px;background-color:transparent;border:none;margin-top:8px}.p1-2bbded{width:450px;margin-top:8px;font-size:14px}.p2-5b1a56{margin-left:80px}.m2-92c0a5{margin-top:15px;margin-left:14px;height:64px;width:412px}.q0-9ce5ab{width:50px}.e0-ff081d,.q0-9ce5ab{background-color:transparent;font-size:12px;border:none;margin-left:14px;margin-top:8px}.e0-ff081d{width:58px}.q1-94d325{margin-left:8px}.e1-6af03a,.q1-94d325{height:22px;width:360px;font-size:12px}.e2-4f4325{background-color:transparent;width:200px;font-size:12px;border:none;margin-left:70px;color:#f76339}.submit-816732{margin-left:164px;margin-top:6px;float:left;width:120px;height:28px;background:url(...);cursor:pointer;border:none;color:#fff}.submit-816732:hover{background:url(...) no-repeat 0 -28px}.close-569292{border:none;float:right;margin-right:6px;width:18px;height:18px;background:url(...);cursor:pointer}.close-569292:hover{background-image:url(...)}.heiping-d6efe8{position:absolute;top:0;left:0;width:100%;height:100%}.content-2d005d{position:relative;top:50%;left:50%;width:350px;height:196px;background:url(data:image/png;base64,...) no-repeat;margin-top:-98px;margin-left:-175px}.problemClose-c94df9{float:right;width:16px;height:16px;margin-right:8px;margin-top:8px;background:url(...) no-repeat 50%;cursor:pointer;border:none}.problemClose-c94df9:hover{background-image:url(...)}.problemCloseOk-e7fb88{margin-left:113px;margin-top:54px;float:left;width:120px;height:28px;background:url(...);border:none;cursor:pointer}.problemCloseOk-e7fb88:hover{background:url(...)}.problemCloseOkTX-1b4c8c{margin-left:202px;margin-top:70px;float:left;width:60px}.problemIcon-29f5ca{margin-left:14px;margin-top:2px;float:left;width:18px;height:18px;background:url(...)}.problemIconInput-2d3d2e{margin-left:11px;margin-top:-2px;float:left;background-color:transparent;font-size:16px;border:none;color:#fff}
#   </style>
#   <style type="text/css">
# ...
#    </style>
#   </div>
#   <div id="live_code" style="display:none">
#    <div class="live_div">
#     <span class="rtmp_title">
#      rtmp地址:
#     </span>
#     <input class="rtmp_value" id="rtmp_url" readonly="" type="text" value=""/>
#     <a class="primary_button01" href="javascript:;" id="copy_rtmp_url">
#      复制
#     </a>
#    </div>
#    <div class="live_div">
#     <span class="rtmp_title">
#      直播码:
#     </span>
#     <textarea class="rtmp_value" id="rtmp_val" readonly="" style="height:54px;" type="text"></textarea>
#     <a class="primary_button01" href="javascript:;" id="copy_rtmp_val">
#      复制
#     </a>
#     <div class="live-info-modal-setting" style="padding-left: 91px;display: block;width: 100%;">
#      <div class="room-setting-notice" style="display: inline-block;font-size: 12px;">
#       <span style="color: orangered;">
#        自动填写推流码已上线，
#       </span>
#       <a class="intro-dymgr-entry" href="https://www.douyu.com/cms/zhibo/201803/12/7339.shtml" style="color: #3B9EEB;" target="_blank">
#        点此了解
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="live_div">
#     <p style="width: 292px; margin-left: 51px;">
#      <strong>
#       注：
#      </strong>
#      <br/>
#      1、每次点击获取推流码都会重新生成直播码，每个直播码的有效期为5分钟。
#      <br/>
#      2、只有切换推流线路才会导致rtmp地址发生变化。
#     </p>
#    </div>
#   </div>
#   <div class="task-case">
#    <div class="task-top">
#     <div class="task-tabs-item task-tabs-item-first active" data-tab="recommend">
#      <span>
#       推荐任务
#      </span>
#     </div>
#     <div class="task-tabs-item" data-tab="web-game">
#      <span>
#       页游任务
#      </span>
#     </div>
#     <div class="task-tabs-item" data-tab="ios-game">
#      <span>
#       苹果任务
#      </span>
#     </div>
#     <div class="task-tabs-item" data-tab="android-game">
#      <span>
#       安卓任务
#      </span>
#     </div>
#     <div class="task-tabs-item" data-tab="novice">
#      <span>
#       新手任务
#      </span>
#     </div>
#     <div class="task-tabs-item" data-tab="record">
#      <span>
#       领取记录
#      </span>
#     </div>
#     <div class="task-close">
#     </div>
#    </div>
#    <div class="task-content-wrap">
#     <div class="task-content task-loading recommend active">
#     </div>
#     <div class="task-content task-loading web-game">
#     </div>
#     <div class="task-content task-loading ios-game">
#     </div>
#     <div class="task-content task-loading android-game">
#     </div>
#     <div class="task-content task-loading novice">
#     </div>
#     <div class="task-content task-loading record">
#     </div>
#    </div>
#   </div>
#   <div class="RichMan">
#    <div class="RichMan-switch">
#    </div>
#    <div class="RichMan-pendant">
#     <div class="rM-slogan">
#      <div class="rM-day rM-hide">
#       --
#      </div>
#     </div>
#     <div class="rM-pendant">
#     </div>
#     <div class="rM-geeContainer" id="rM-gee">
#      <span class="rM-geeCls">
#       ×
#      </span>
#      <span class="rM-icon">
#      </span>
#      <p class="rM-geeTitle">
#       <span class="rM-cff6700">
#        验证通过
#       </span>
#       后可以获得宝箱礼物
#      </p>
#      <div class="rM-area">
#       <div class="captcha-gt rM-captcha" id="rM-gee-captcha-gt">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="RichMan-rank">
#    </div>
#   </div>
#   <div class="pk-qualifier-wrap" id="J_pR_container" style="display: none">
#    <div class="pk-qualifier">
#     <div class="pk-qualifier-close">
#     </div>
#     <div class="pk-qualifier-title">
#      <div class="pk-qualifier-winner">
#       <a class="qualifier-winner-avatar" href="javascript:;" target="_blank">
#        <img src="https://shark.douyucdn.cn//app/douyu/activity/res/pkQualifier/wait.png?v=20180714"/>
#       </a>
#       <span class="qualifier-winner-name">
#        敬请期待
#       </span>
#      </div>
#     </div>
#     <div class="pk-qualifier-tabs">
#      <div class="pk-qualifier-tab" data-index="0">
#       <span class="on">
#        积分周榜
#       </span>
#      </div>
#      <div class="pk-qualifier-tab" data-index="1">
#       <span>
#        本月段位榜
#       </span>
#      </div>
#      <div class="pk-qualifier-tab" data-index="2">
#       <span>
#        规则与奖励
#       </span>
#      </div>
#     </div>
#     <div class="pk-qualifier-content">
#      <div class="pk-integral-tabs">
#       <span class="pk-integral-tab1 on" data-tab="0">
#        本周积分榜
#       </span>
#       <span class="pk-integral-tab2" data-tab="1">
#        上周积分榜
#       </span>
#      </div>
#      <div class="pk-score-rank" data-rank="0">
#       <div class="qualifier-list pk-week-integral J_week_list_wrap" data-score="0">
#        <ul class="qualifier-list-wrap J_week_list">
#        </ul>
#       </div>
#       <div class="qualifier-list-wrap cur-qualifier-anchor" data-score="0">
#        <span class="qualifier-order">
#         暂无排名
#        </span>
#        <a class="qualifier-avatar" href="javascript:;">
#         <img src="https://shark.douyucdn.cn//app/douyu/activity/res/pkQualifier/default.png?v=20180714"/>
#        </a>
#        <span class="qualifier-name-col">
#         <a class="qualifier-nickname" href="javascript:;">
#          --
#         </a>
#         <span class="qualifier-win-num J_record_entry">
#          暂无连胜
#         </span>
#        </span>
#        <span class="qualifier-level" data-grading-level="0">
#        </span>
#        <span class="qualifier-integral">
#         积分：
#         <i>
#          --
#         </i>
#        </span>
#       </div>
#       <div class="qualifier-list pk-lastweek-integral" data-score="1" style="display: none">
#        <ul class="qualifier-list-wrap">
#        </ul>
#       </div>
#      </div>
#      <div class="qualifier-list pk-month-grading J_lweek_list_wrap" data-rank="1" style="display: none;">
#       <ul class="qualifier-list-wrap J_lweek_list">
#       </ul>
#      </div>
#      <div class="qualifier-list-wrap cur-month-anchor" data-rank="1" style="display: none;">
#       <span class="qualifier-order">
#        --
#       </span>
#       <a class="qualifier-avatar" href="javascript:;">
#        <img src="https://shark.douyucdn.cn//app/douyu/activity/res/pkQualifier/default.png?v=20180714"/>
#       </a>
#       <span class="qualifier-name-col">
#        <a class="qualifier-nickname" href="javascript:;">
#         --
#        </a>
#        <span class="qualifier-integral">
#         积分：
#         <i>
#          --
#         </i>
#        </span>
#       </span>
#       <span class="qualifier-level" data-grading-level="0">
#       </span>
#      </div>
#      <div class="qualifier-list rule-and-award" data-rank="2" style="display: none;">
#       <div class="qualifier-rule-title">
#       </div>
#       <div class="qualifier-col-title">
#        <i class="col-title1">
#        </i>
#        <span>
#         积分规则
#        </span>
#       </div>
#       <div class="integral-content">
#        <div class="integral-rule">
#         <div class="col-integral-title">
#          <span class="col-integral-title-txt">
#           胜负奖励
#          </span>
#          <span class="col-title-attention">
#           终结对方2连胜以上+5积分
#          </span>
#         </div>
#         <div class="integral-rule-table integral-rule-table1">
#          <div class="integral-result-col">
#           <p class="integral-result-row">
#            +20积分（随机PK为30）
#           </p>
#          </div>
#          <div class="integral-result-col integral-result-draw">
#           <p class="integral-result-row">
#            0积分
#           </p>
#          </div>
#          <div class="integral-result-col integral-result-lose">
#           <p class="integral-result-row">
#            -15积分
#           </p>
#          </div>
#         </div>
#         <div class="col-integral-title">
#          <span class="col-integral-title-txt">
#           连胜奖励
#          </span>
#         </div>
#         <div class="integral-rule-table integral-rule-table2">
#          <div class="integral-result-col">
#           <p class="integral-result-row">
#            +5积分
#           </p>
#          </div>
#          <div class="integral-result-col">
#           <p class="integral-result-row">
#            +10积分
#           </p>
#          </div>
#          <div class="integral-result-col">
#           <p class="integral-result-row">
#            +15积分
#           </p>
#          </div>
#         </div>
#         <div class="col-integral-title">
#          <span class="col-integral-title-txt">
#           PK值奖励
#          </span>
#         </div>
#         <div class="integral-rule-table integral-rule-table3">
#          <div class="integral-result-col">
#           <p class="integral-result-dot">
#            单场PK贡献值每增加1000
#           </p>
#           <p class="integral-result-row">
#            +3积分（随机PK为5）
#           </p>
#          </div>
#         </div>
#         <div class="col-integral-title">
#          <span class="col-integral-title-txt">
#           场次奖励
#          </span>
#         </div>
#         <div class="integral-rule-table integral-rule-table4">
#          <div class="integral-result-col">
#           <p class="integral-result-dot">
#            单日PK达3场
#           </p>
#           <p class="integral-result-row">
#            +20积分
#           </p>
#          </div>
#          <div class="integral-result-col">
#           <p class="integral-result-dot">
#            单日PK达10场
#           </p>
#           <p class="integral-result-row">
#            +50积分
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="integral-attention">
#         <p>
#          注意：
#         </p>
#         <p>
#          1.积分为0时，PK失败不扣积分，不足15则扣减至0
#         </p>
#         <p>
#          2.与同一主播单日PK超过3次或每周PK超过10次后，PK不计胜负及场次积分，仅计PK值积分
#         </p>
#         <p>
#          3.PK异常中断或一方取消未完成的，PK不计胜负及场次积分，仅计战力积分
#         </p>
#        </div>
#       </div>
#       <div class="qualifier-col-title">
#        <i class="col-title2">
#        </i>
#        <span>
#         段位规则
#        </span>
#       </div>
#       <div class="integral-content">
#        <div class="grading-rule">
#         <div class="grading-rule-row">
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon1">
#            </i>
#            青铜I
#           </span>
#           <span class="grading-rule-col2">
#            50积分以内
#           </span>
#          </div>
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon2">
#            </i>
#            青铜II
#           </span>
#           <span class="grading-rule-col2">
#            50积分
#           </span>
#          </div>
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon3">
#            </i>
#            青铜III
#           </span>
#           <span class="grading-rule-col2">
#            150积分
#           </span>
#          </div>
#         </div>
#         <div class="grading-rule-row">
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon4">
#            </i>
#            白银I
#           </span>
#           <span class="grading-rule-col2">
#            300积分
#           </span>
#          </div>
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon5">
#            </i>
#            白银II
#           </span>
#           <span class="grading-rule-col2">
#            1000积分
#           </span>
#          </div>
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon6">
#            </i>
#            白银III
#           </span>
#           <span class="grading-rule-col2">
#            2000积分
#           </span>
#          </div>
#         </div>
#         <div class="grading-rule-row">
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon7">
#            </i>
#            黄金I
#           </span>
#           <span class="grading-rule-col2">
#            5000积分
#           </span>
#          </div>
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon8">
#            </i>
#            黄金II
#           </span>
#           <span class="grading-rule-col2">
#            10000积分
#           </span>
#          </div>
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon9">
#            </i>
#            黄金III
#           </span>
#           <span class="grading-rule-col2">
#            20000积分
#           </span>
#          </div>
#         </div>
#         <div class="grading-rule-row">
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            <i class="grading-level-icon10">
#            </i>
#            铂金段位
#           </span>
#           <span class="grading-rule-col2">
#            50000+积分
#           </span>
#          </div>
#          <div class="grading-rule-col">
#           <span class="grading-rule-col1">
#            钻石段位
#           </span>
#           <span class="grading-rule-col2">
#            待开放
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="qualifier-col-title">
#        <i class="col-title3">
#        </i>
#        <span>
#         掉段规则
#        </span>
#       </div>
#       <div class="integral-content">
#        <div class="lose-grading-rule">
#         <p>
#          每月对铂金及以下段位进行掉段处理，每次掉两个小段位，如黄金II掉段白银III
#         </p>
#        </div>
#       </div>
#       <div class="qualifier-award-title">
#       </div>
#       <div class="qualifier-col-title">
#        <i class="col-title4">
#        </i>
#        <span>
#         周赛奖励
#        </span>
#        <span class="col-title-note">
#         <em>
#          排名越靠前推荐位流量越多哟（奖励均持续7天）
#         </em>
#        </span>
#       </div>
#       <div class="integral-content">
#        <div class="pk-week-award">
#         <div class="pk-week-award1">
#          <div class="award-list-top1">
#           <div class="award-list-img award-list-img1">
#           </div>
#           <p>
#            颜值分区4号位
#           </p>
#          </div>
#          <div class="award-list-top1">
#           <div class="award-list-img award-list-img2">
#           </div>
#           <p>
#            娱乐页2号位(移动端)
#           </p>
#          </div>
#          <div class="award-list-top1">
#           <div class="award-list-img award-list-img3">
#           </div>
#           <p>
#            封面角标
#           </p>
#          </div>
#          <div class="award-list-top1">
#           <div class="award-list-img award-list-img4">
#           </div>
#           <p>
#            周冠军代言
#           </p>
#          </div>
#         </div>
#         <div class="pk-week-award2">
#          <div class="award-list-top1">
#           <div class="award-list-img award-list-img3">
#           </div>
#           <p>
#            封面角标
#           </p>
#          </div>
#          <div class="award-list-top1">
#           <div class="award-list-img award-list-img1">
#           </div>
#           <p>
#            颜值分区4号位
#           </p>
#          </div>
#          <div class="award-list-top1">
#           <div class="award-list-img award-list-img2">
#           </div>
#           <p>
#            娱乐页2号位(移动端)
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="qualifier-col-title">
#        <i class="col-title5">
#        </i>
#        <span>
#         段位奖励
#        </span>
#        <span class="col-title-note">
#         <em>
#          白银及以上段位，
#         </em>
#         拥有直播公告飘屏奖励
#        </span>
#       </div>
#       <div class="integral-content">
#        <div class="grading-award">
#         <p>
#          更多神秘奖励及尊贵特权，即将开启~
#         </p>
#        </div>
#        <div class="integral-attention">
#         <p>
#          1.禁止作弊刷分或恶意取消PK，一经举报查实则取消活动资格
#         </p>
#         <p>
#          2.活动奖励每周一凌晨结算发放
#         </p>
#         <p>
#          3.本活动最终解释权归斗鱼直播所有
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="pk-record" data-score="2" style="display: none;">
#    </div>
#   </div>
#  </body>
# </html>
